# %%
import tensorflow as tf

# %% [markdown]
# Dataset

# %%
dataset_path = "./dataset/"

train_data = tf.keras.utils.audio_dataset_from_directory(
    dataset_path,
    batch_size=4,
    shuffle=True,
    validation_split=0.2,
    subset="training",
    output_sequence_length=48000,
    ragged=False,
    label_mode="categorical",
    labels="inferred",
    sampling_rate=None,
    seed=59
)

validation_data = tf.keras.utils.audio_dataset_from_directory(
    dataset_path,
    batch_size=4,
    shuffle=True,
    validation_split=0.2,
    subset="validation",
    output_sequence_length=48000,
    ragged=False,
    label_mode="categorical",
    labels="inferred",
    sampling_rate=None,
    seed=59
)
# Out:
# Found 1769 files belonging to 21 classes.
# Using 1416 files for training.
# Found 1769 files belonging to 21 classes.
# Using 353 files for validation.

# %% [markdown]
# Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(32, kernel_size=80, strides=16, activation="relu", input_shape=(48000, 1)),
    tf.keras.layers.MaxPooling1D(4),
    tf.keras.layers.Conv1D(32, kernel_size=3, activation="relu"),
    tf.keras.layers.MaxPooling1D(4),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation="relu"),
    tf.keras.layers.MaxPooling1D(4),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation="relu"),
    tf.keras.layers.MaxPooling1D(4),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(21, activation="softmax")
])
# Out:
# c:\Users\I\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 2996, 32)       │         2,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 749, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 747, 32)        │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 186, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 184, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 46, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 44, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 704)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 21)             │        14,805 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,061 (152.58 KB)
#  Trainable params: 39,061 (152.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(), 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Train

# %%
history = model.fit(
    train_data, 
    validation_data=validation_data, 
    epochs=20)
# Out:
# Epoch 1/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 48s 136ms/step - accuracy: 0.4879 - loss: 1.5960 - val_accuracy: 0.5326 - val_loss: 1.4168
# Epoch 2/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 43s 120ms/step - accuracy: 0.6791 - loss: 1.0179 - val_accuracy: 0.6799 - val_loss: 1.0027
# Epoch 3/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 47s 134ms/step - accuracy: 0.7567 - loss: 0.7645 - val_accuracy: 0.7082 - val_loss: 0.8288
# Epoch 4/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 53s 151ms/step - accuracy: 0.8561 - loss: 0.4673 - val_accuracy: 0.7790 - val_loss: 0.6983
# Epoch 5/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 58s 163ms/step - accuracy: 0.8650 - loss: 0.4106 - val_accuracy: 0.8215 - val_loss: 0.7065
# Epoch 6/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 44s 123ms/step - accuracy: 0.8893 - loss: 0.3379 - val_accuracy: 0.7592 - val_loss: 0.8367
# Epoch 7/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 48s 136ms/step - accuracy: 0.9220 - loss: 0.2498 - val_accuracy: 0.8357 - val_loss: 0.5825
# Epoch 8/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 43s 121ms/step - accuracy: 0.8954 - loss: 0.3119 - val_accuracy: 0.7564 - val_loss: 1.5778
# Epoch 9/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 42s 118ms/step - accuracy: 0.9321 - loss: 0.2318 - val_accuracy: 0.8527 - val_loss: 0.5283
# Epoch 10/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 47s 132ms/step - accuracy: 0.9605 - loss: 0.1227 - val_accuracy: 0.8244 - val_loss: 0.7212
# Epoch 11/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 48s 134ms/step - accuracy: 0.9077 - loss: 0.3874 - val_accuracy: 0.8074 - val_loss: 0.6953
# Epoch 12/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 47s 132ms/step - accuracy: 0.9827 - loss: 0.0808 - val_accuracy: 0.8272 - val_loss: 0.6403
# Epoch 13/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.9652 - loss: 0.1190 - val_accuracy: 0.7932 - val_loss: 1.0283
# Epoch 14/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 43s 120ms/step - accuracy: 0.9730 - loss: 0.1007 - val_accuracy: 0.8499 - val_loss: 0.5616
# Epoch 15/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 40s 112ms/step - accuracy: 0.9858 - loss: 0.0678 - val_accuracy: 0.8470 - val_loss: 0.6178
# Epoch 16/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.9857 - loss: 0.0648 - val_accuracy: 0.7904 - val_loss: 0.9891
# Epoch 17/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 54s 152ms/step - accuracy: 0.9628 - loss: 0.1414 - val_accuracy: 0.8725 - val_loss: 0.5394
# Epoch 18/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 50s 142ms/step - accuracy: 0.9908 - loss: 0.0385 - val_accuracy: 0.8867 - val_loss: 0.5509
# Epoch 19/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9966 - loss: 0.0241 - val_accuracy: 0.8754 - val_loss: 0.5970
# Epoch 20/20
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 53s 150ms/step - accuracy: 0.9980 - loss: 0.0146 - val_accuracy: 0.8754 - val_loss: 0.6108

# %%
model.save("weights/audio_classification.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
